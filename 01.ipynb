# %% [markdown]
# # Q1. Write a python program to read and display an image.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img1 = mpimg.imread('./imgs/naruto.jpg')
imgplot = plt.imshow(img1)
plt.show()
